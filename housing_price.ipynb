# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# California Housing data from sklearn

# %%
from sklearn.datasets import fetch_california_housing

# %%
california=fetch_california_housing()

# %% [markdown]
# type that we get using sklearn withing dataset

# %%
type(california)
# Out:
# sklearn.utils._bunch.Bunch

# %%
california.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
##just checking the description of dataset
print(california.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %%
print(california.data)
# Out:
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]

# %%
print(california.target)
# Out:
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]

# %%
print(california.feature_names)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
print(california.target_names)
# Out:
# ['MedHouseVal']

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"
boston = pd.read_csv(url)
print(boston.head())
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
print (boston.keys)
# Out:
# <bound method NDFrame.keys of         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# ...

# %%
boston.keys()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
print(boston.dis)
# Out:
# 0      4.0900
# 1      4.9671
# 2      4.9671
# 3      6.0622
# 4      6.0622
#         ...
# 501    2.4786
# 502    2.2875
# 503    2.1675
# 504    2.3889
# 505    2.5050
# Name: dis, Length: 506, dtype: float64

# %%
type(boston)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Boston is in a prepared manner dataset with features

# %%
print(boston.head())
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# Caliafornia is better

# %%
dataset=pd.DataFrame(california.data,columns=california.feature_names)

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
#this is done to check the targets as price in our dataset
dataset['price']=california.target

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   price       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
dataset.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# price         0
# dtype: int64

# %%
dataset.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %% [markdown]
# # dataset Analysis

# %%
##Exploration data analysis
#we check the correlation and dependencies in regression. if dependents are high then model performance will be high.
dataset.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...

# %%
import seaborn as sns
sns.pairplot(dataset)

# %% [markdown]
# plt.scatter(dataset['AveOccup'], dataset['price'])
# plt.xlim(0, 10)   # show only range 0–10 for AveOccup
# plt.xlabel("AveOccup")
# plt.ylabel("price")
# plt.show()

# %% [markdown]
# # confirm Regression

# %%
import seaborn as sns
sns.regplot(
    x="Population", y="price", data=dataset,
    scatter_kws={"s": 10, "alpha": 0.5},   # smaller, transparent points
    line_kws={"color": "red"}              # regression line in red
)
# Out:
# <Axes: xlabel='Population', ylabel='price'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Original dataset (with capped values at 5.0)
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# ---- Left: With capped values ----
sns.regplot(x="MedInc", y="price", data=dataset,
            scatter_kws={"s": 10, "alpha": 0.5},
            line_kws={"color": "red"},
            ax=axes[0])
axes[0].set_title("With capped values (price=5.0)")

# ---- Right: After removing capped values ----
dataset_uncapped = dataset[dataset["price"] < 5.0]

sns.regplot(x="Population", y="price", data=dataset_uncapped,
            scatter_kws={"s": 10, "alpha": 0.5},
            line_kws={"color": "red"},
            ax=axes[1])
axes[1].set_title("Without capped values")

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Split figure into 3 plots
fig, axes = plt.subplots(1, 3, figsize=(20, 6))

# ---- 1. Linear Regression (with capped values) ----
sns.regplot(x="MedInc", y="price", data=dataset,
            scatter_kws={"s": 10, "alpha": 0.5},
            line_kws={"color": "red"},
            ax=axes[0])
axes[0].set_title("Linear (with capped values)")

# ---- 2. Linear Regression (without capped values) ----
dataset_uncapped = dataset[dataset["price"] < 5.0]

sns.regplot(x="MedInc", y="price", data=dataset_uncapped,
            scatter_kws={"s": 10, "alpha": 0.5},
            line_kws={"color": "red"},
            ax=axes[1])
axes[1].set_title("Linear (without capped values)")

# ---- 3. Polynomial Regression (order=2) ----
sns.regplot(x="MedInc", y="price", data=dataset_uncapped,
            order=2,  # quadratic fit
            scatter_kws={"s": 10, "alpha": 0.5},
            line_kws={"color": "green"},
            ax=axes[2])
axes[2].set_title("Polynomial Regression (order=2)")

plt.show()

# %%
#independent and non independent features
x=dataset.iloc[:,:-1]
y=dataset.iloc[:,]

# %%
x.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
y.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %% [markdown]
# # we try train test split for Regression model

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_test
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20046  1.6812      25.0  4.192201   1.022284      1392.0  3.877437     36.06
# 3024   2.5313      30.0  5.039384   1.193493      1565.0  2.679795     35.14
# 15663  3.4801      52.0  3.977155   1.185877      1310.0  1.360332     37.80
# 20484  5.7376      17.0  6.163636   1.020202      1705.0  3.444444     34.28
# 9814   3.7250      34.0  5.492991   1.028037      1063.0  2.483645     36.62
# ...       ...       ...       ...        ...         ...       ...       ...
# 17505  2.9545      47.0  4.195833   1.020833       581.0  2.420833     37.36
# 13512  1.4891      41.0  4.551852   1.118519       994.0  3.681481     34.11
# 10842  3.5120      16.0  3.762287   1.075614      5014.0  2.369565     33.67
# 16559  3.6500      10.0  5.502092   1.060371      5935.0  3.547519     37.82
# 5786   3.0520      17.0  3.355781   1.019695      4116.0  2.614994     34.15
#
#        Longitude
# 20046    -119.01
# ...

# %%
x_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 7061   4.1312      35.0  5.882353   0.975490      1218.0  2.985294     33.93
# 14689  2.8631      20.0  4.401210   1.076613       999.0  2.014113     32.79
# 17323  4.2026      24.0  5.617544   0.989474       731.0  2.564912     34.59
# 10056  3.1094      14.0  5.869565   1.094203       302.0  2.188406     39.26
# 15750  3.3068      52.0  4.801205   1.066265      1526.0  2.298193     37.77
# ...       ...       ...       ...        ...         ...       ...       ...
# 11284  6.3700      35.0  6.129032   0.926267       658.0  3.032258     33.78
# 11964  3.0500      33.0  6.868597   1.269488      1753.0  3.904232     34.02
# 5390   2.9344      36.0  3.986717   1.079696      1756.0  3.332068     34.03
# 860    5.7192      15.0  6.395349   1.067979      1777.0  3.178891     37.58
# 15795  2.5755      52.0  3.402576   1.058776      2619.0  2.108696     37.77
#
#        Longitude
# 7061     -118.02
# ...

# %% [markdown]
# # Standardrize our test and train sets

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
#fit_transform is not used with test data for our model does'nt have much information about standardized train_set, our aim is to get to the global minima
x_test=scaler.transform(x_test)

import pickle
with open("scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)

# %% [markdown]
# # model training will be done through linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regression.coef_)
# Out:
# [[ 1.90484248e+00 -7.78754118e-16 -6.98444223e-16  5.86548641e-16
#    1.13596734e-15  1.53241594e-16  7.04422096e-16 -8.91168178e-16]
#  [ 6.63077016e-15  1.26131971e+01  7.10542736e-15 -7.99360578e-15
#   -6.18949336e-15  1.88737914e-15 -3.10862447e-15  2.77555756e-15]
#  [-1.09213630e-15  8.88178420e-16  2.45348438e+00  2.77555756e-16
#    3.88578059e-16 -1.38777878e-16  1.44328993e-15  9.43689571e-16]
#  [ 3.45624679e-16  1.38777878e-17 -3.26128013e-16  4.47482496e-01
#   -1.54390389e-16  8.58688121e-17 -7.63278329e-17 -1.64798730e-16]
#  [ 1.01281384e-12  6.30606678e-13  3.19744231e-14 -4.58300065e-13
#    1.14018573e+03 -1.40998324e-13  2.22932783e-13 -9.42579348e-14]
#  [ 5.56583353e-14  8.54871729e-15  4.99600361e-15 -2.02893258e-14
#   -1.73246834e-14  1.23732074e+01 -1.37390099e-14 -1.30381816e-14]
#  [ 1.97505106e-16 -1.05471187e-15  1.83186799e-15 -9.43689571e-16
#    6.34475111e-16  1.38777878e-16  2.13566827e+00  1.48839274e-15]
# ...

# %%
print(regression.intercept_)
# Out:
# [ 3.87689155e+00  2.85753738e+01  5.43812463e+00  1.09803314e+00
#   1.42792733e+03  3.11923650e+00  3.56506693e+01 -1.19584102e+02
#   2.06923961e+00]

# %%
print("Intercepts:", np.round(regression.intercept_, 3))
# Out:
# Intercepts: [ 3.877000e+00  2.857500e+01  5.438000e+00  1.098000e+00  1.427927e+03
#   3.119000e+00  3.565100e+01 -1.195840e+02  2.069000e+00]

# %%
##parameterss the model is trained
regression.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'positive': False,
#  'tol': 1e-06}

# %%
#prediction with test data
reg_pred=regression.predict(x_test)

# %% [markdown]
# # Assumptions

# %%
reg_pred
# Out:
# array([[   1.6812    ,   25.        ,    4.19220056, ...,   36.06      ,
#         -119.01      ,    0.72604907],
#        [   2.5313    ,   30.        ,    5.03938356, ...,   35.14      ,
#         -119.46      ,    1.76743383],
#        [   3.4801    ,   52.        ,    3.97715472, ...,   37.8       ,
#         -122.44      ,    2.71092161],
#        ...,
#        [   3.512     ,   16.        ,    3.76228733, ...,   33.67      ,
#         -117.91      ,    2.07465531],
#        [   3.65      ,   10.        ,    5.50209205, ...,   37.82      ,
#         -121.28      ,    1.57371395],
#        [   3.052     ,   17.        ,    3.35578145, ...,   34.15      ,
#         -118.24      ,    1.82744133]])

# %%
##scater plot for prediction
plt.scatter(reg_pred,y_test)

# %%
residuals=y_test-reg_pred

# %%
residuals
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# 20046  3.552714e-15  1.065814e-14  1.776357e-15  4.440892e-16  1.364242e-12
# 3024   1.776357e-15  7.105427e-15  8.881784e-16  4.440892e-16  6.821210e-13
# 15663 -4.440892e-16  0.000000e+00  1.776357e-15  0.000000e+00 -1.136868e-12
# 20484 -2.664535e-15 -7.105427e-15  1.776357e-15  0.000000e+00 -4.547474e-13
# 9814  -4.440892e-16  0.000000e+00  8.881784e-16  0.000000e+00 -2.273737e-13
# ...             ...           ...           ...           ...           ...
# 17505  1.776357e-15  0.000000e+00  1.776357e-15  0.000000e+00  0.000000e+00
# 13512  6.217249e-15  0.000000e+00  0.000000e+00  6.661338e-16  1.364242e-12
# 10842 -2.664535e-15  2.842171e-14  3.996803e-15  6.661338e-16 -2.728484e-12
# 16559 -6.661338e-15  4.263256e-14  0.000000e+00  8.881784e-16 -3.637979e-12
# 5786  -1.332268e-15  2.131628e-14  4.440892e-15  4.440892e-16 -1.818989e-12
#
# ...

# %%
##plotting the residuals
sns.kdeplot(residuals, shade=True)
plt.show()
# Out:
# C:\Users\somir\AppData\Local\Temp\ipykernel_9796\261948906.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(residuals, shade=True)

# %%
##scatterplot wrt predictions and residuals
plt.scatter(reg_pred,residuals)

# %%
plt.scatter(reg_pred, residuals, alpha=0.6)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlim(0, 2000)   # adjust based on your data
plt.show()

# %%
import seaborn as sns

sns.set_style("whitegrid")
plt.figure(figsize=(8,5))
plt.scatter(reg_pred, residuals, alpha=0.5, edgecolors="k")
plt.axhline(y=0, color="red", linestyle="--")
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residuals vs Fitted Values")
plt.show()

# %% [markdown]
# # Performance matrices

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
print(r2_score(y_test, reg_pred))
# Out:
# 0.05858305042575291
# 0.058951975830741646
# 0.24280027971718163
# 0.9550855814006852

# %% [markdown]
# # New Data Prediction

# %%
california.data[0].shape
 #1d data
# Out:
# (8,)

# %%
california.data[0].reshape(1,-1).shape
# Out:
# (1, 8)

# %%
california.data[0].reshape(1,-1)
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698,    1.02380952,
#          322.        ,    2.55555556,   37.88      , -122.23      ]])

# %%
scaler.transform(california.data[0].reshape(1,-1))
# Out:
# a:\Python\local_californiahoisungprice\californiahousingprices\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ 2.33526315,  0.98504972,  0.63012521, -0.16586931, -0.96995366,
#         -0.04555657,  1.04385626, -1.32105914]])

# %%
regression.predict(california.data[0].reshape(1,-1))
# Out:
# array([[ 1.97350861e+01,  5.45716454e+02,  2.25735711e+01,
#          1.55616998e+00,  3.68567732e+05,  3.47396553e+01,
#          1.16549783e+02, -3.64393790e+02,  8.43310221e+01]])

# %% [markdown]
# # Pickling the model file for Deployment

# %%
import pickle

with open("regmodel.pkl", "wb") as f:
    pickle.dump(regression, f)

# %%
pickled_model = pickle.load(open('regmodel.pkl', 'rb'))
print(pickled_model.predict(x_test))
# Out:
# [[   1.6812       25.            4.19220056 ...   36.06
#   -119.01          0.72604907]
#  [   2.5313       30.            5.03938356 ...   35.14
#   -119.46          1.76743383]
#  [   3.4801       52.            3.97715472 ...   37.8
#   -122.44          2.71092161]
#  ...
#  [   3.512        16.            3.76228733 ...   33.67
#   -117.91          2.07465531]
#  [   3.65         10.            5.50209205 ...   37.82
#   -121.28          1.57371395]
#  [   3.052        17.            3.35578145 ...   34.15
#   -118.24          1.82744133]]

# %%
#Line 86 and line 96 are similar which means our pickle file is working perfectly!
pickled_model.predict(scaler.transform(california.data[0].reshape(1,-1)))
# Out:
# a:\Python\local_californiahoisungprice\californiahousingprices\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[   8.3252    ,   41.        ,    6.98412698,    1.02380952,
#          322.        ,    2.55555556,   37.88      , -122.23      ,
#            4.14333441]])
